# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bdi2_df = pd.read_csv('../teis-JesseCrawford89/data/NSS data_BDI2 scores_20200101-20230131_20241106.csv')

bdi2_df['testDate'] = pd.to_datetime(bdi2_df['testDate'])

bdi3_df = pd.read_excel('../teis-JesseCrawford89/data/NSS data_BDI3 Scores 20230101 20240630_Compiled_20241107.xlsx')

bdi3_df['Adaptive-Self Care Date of Testing'] = pd.to_datetime(bdi3_df['Adaptive-Self Care Date of Testing'])

eco_df = pd.read_excel('../teis-JesseCrawford89/data/NSS_ECO Data Ind 3 FFY 2023-24 20241211.xlsx',sheet_name='ECO with Exit23-24 ')

entry_exit = eco_df[(eco_df['OC1 Data Check']==1)][['CHILD_ID','ECO_Entry_DATE','ECO_Exit_DATE','BDI 3\nECO_Entry_DATE','BDI 3\nECO_Exit_DATE','BDI2 Entry Date']]

entry_exit.rename(columns={'CHILD_ID':'TEIDS Child ID'}, inplace=True)

bdi3_exit = entry_exit.merge(bdi3_df,how='inner',left_on=['TEIDS Child ID','BDI 3\nECO_Exit_DATE'],right_on=['TEIDS Child ID','Adaptive-Self Care Date of Testing'])

bdi3_entry = entry_exit.merge(bdi3_df,how='inner',left_on=['TEIDS Child ID','BDI 3\nECO_Entry_DATE'],right_on=['TEIDS Child ID','Adaptive-Self Care Date of Testing'])

bdi2_entry_subdomains = entry_exit.merge(bdi2_df,how='inner',left_on=['TEIDS Child ID','BDI2 Entry Date'],right_on=['Student TEIDS ID','testDate'])

bdi2_entry = bdi2_df[bdi2_df['studentAssessmentID'].isin(bdi2_entry_subdomains['studentAssessmentID'])]
# Out:
# C:\Users\Jesse\AppData\Local\Temp\ipykernel_17168\1368231529.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   bdi2_df = pd.read_csv('../teis-JesseCrawford89/data/NSS data_BDI2 scores_20200101-20230131_20241106.csv')

# %%
test_ids = bdi3_exit[(bdi3_exit['TEIDS Child ID'].isin(bdi3_entry['TEIDS Child ID']))|(bdi3_exit['TEIDS Child ID'].isin(bdi2_entry['Student TEIDS ID']))]['TEIDS Child ID']

# %%
bdi3_test = bdi3_df[bdi3_df['TEIDS Child ID'].isin(test_ids)]

# %%
bdi3_test
# Out:
#        Last Name  First Name  Gender  Date of Birth  \
# 3            NaN         NaN     NaN            NaN
# 4            NaN         NaN     NaN            NaN
# 13           NaN         NaN     NaN            NaN
# 14           NaN         NaN     NaN            NaN
# 15           NaN         NaN     NaN            NaN
# ...          ...         ...     ...            ...
# 25638        NaN         NaN     NaN            NaN
# 25770        NaN         NaN     NaN            NaN
# 25771        NaN         NaN     NaN            NaN
# 25788        NaN         NaN     NaN            NaN
# 25789        NaN         NaN     NaN            NaN
#
#        Location - Root Level (PC)        Location - Root Level (AH)  \
# 3                             NaN  Tennessee Early Intervention Sys
# 4                             NaN  Tennessee Early Intervention Sys
# 13                            NaN  Tennessee Early Intervention Sys
# 14                            NaN  Tennessee Early Intervention Sys
# 15                            NaN  Tennessee Early Intervention Sys
# ...                           ...                               ...
# 25638                         NaN  Tennessee Early Intervention Sys
# 25770                         NaN  Tennessee Early Intervention Sys
# 25771                         NaN  Tennessee Early Intervention Sys
# 25788                         NaN  Tennessee Early Intervention Sys
# 25789                         NaN  Tennessee Early Intervention Sys
#
#       Location - Sub Level 1  Location - Sub Level 2  Location - Sub Level 3  \
# 3                  Southwest                     NaN                     NaN
# 4              South Central                     NaN                     NaN
# 13       Southeast Tennessee                     NaN                     NaN
# 14       Southeast Tennessee                     NaN                     NaN
# 15             Memphis Delta                     NaN                     NaN
# ...                      ...                     ...                     ...
# 25638       Upper Cumberland                     NaN                     NaN
# 25770         East Tennessee                     NaN                     NaN
# 25771         East Tennessee                     NaN                     NaN
# 25788    Southeast Tennessee                     NaN                     NaN
# 25789    Southeast Tennessee                     NaN                     NaN
#
#        Child ID  ...  Cognitive-Perception and Concepts RS  \
# 3        474848  ...                                  17.0
# 4        474967  ...                                  12.0
# 13       475907  ...                                  17.0
# 14       475907  ...                                  11.0
# 15       476193  ...                                   8.0
# ...         ...  ...                                   ...
# 25638  \t565093  ...                                  16.0
# 25770    565305  ...                                  13.0
# 25771    565305  ...                                  22.0
# 25788       NaN  ...                                   8.0
# 25789    565335  ...                                   8.0
#
#        Cognitive-Perception and Concepts SS  \
# 3                                       6.0
# 4                                       3.0
# 13                                      7.0
# 14                                      1.0
# 15                                      1.0
# ...                                     ...
# 25638                                   9.0
# 25770                                   9.0
# 25771                                  12.0
# 25788                                   2.0
# 25789                                   1.0
#
#        Cognitive-Perception and Concepts PR  \
# 3                                         9
# 4                                         1
# 13                                       16
# 14                                       <1
# 15                                       <1
# ...                                     ...
# 25638                                    37
# 25770                                    37
# 25771                                    75
# 25788                                    <1
# 25789                                    <1
#
#        Cognitive-Perception and Concepts AE  \
# 3                                        32
# 4                                        22
# 13                                       32
# 14                                       18
# 15                                        8
# ...                                     ...
# 25638                                    31
# 25770                                    25
# 25771                                    39
# 25788                                     8
# 25789                                     8
#
#        Cognitive-Perception and Concepts RDI  \
# 3                                      25/90
# 4                        1990-01-01 00:00:00
# 13                                     45/90
# 14                                     <1/90
# 15                                     <1/90
# ...                                      ...
# 25638                                  73/90
# 25770                                  73/90
# 25771                                  97/90
# 25788                                  <1/90
# 25789                                  <1/90
#
#        Cognitive-Perception and Concepts CSS  \
# 3                                      487.0
# 4                                      451.0
# 13                                     487.0
# 14                                     437.0
# 15                                     395.0
# ...                                      ...
# 25638                                  482.0
# 25770                                  464.0
# 25771                                  505.0
# 25788                                  395.0
# 25789                                  395.0
#
#        Cognitive-Perception and Concepts CSS 90%  \
# 3                                      476 - 497
# 4                                      429 - 473
# 13                                     476 - 497
# 14                                     421 - 453
# 15                                     376 - 415
# ...                                          ...
# 25638                                  471 - 493
# 25770                                  450 - 479
# 25771                                  497 - 513
# 25788                                  376 - 415
# 25789                                  376 - 415
#
#        Cognitive-Perception and Concepts Z-Score  \
# 3                                           1.33
# 4                                           2.33
# 13                                          1.00
# 14                                          3.00
# 15                                          3.00
# ...                                          ...
# 25638                                       0.33
# 25770                                       0.33
# 25771                                       0.67
# 25788                                       2.67
# 25789                                       3.00
#
#        Cognitive-Perception and Concepts T-Score  \
# 3                                           37.0
# 4                                           27.0
# 13                                          40.0
# 14                                          20.0
# 15                                          20.0
# ...                                          ...
# 25638                                       47.0
# 25770                                       47.0
# 25771                                       57.0
# 25788                                       23.0
# 25789                                       20.0
#
#       Cognitive-Perception and Concepts NCE
# 3                                        22
# 4                                         1
# 13                                       29
# 14                                       <1
# 15                                       <1
# ...                                     ...
# 25638                                    43
# 25770                                    43
# 25771                                    64
# 25788                                    <1
# 25789                                    <1
#
# [5816 rows x 228 columns]

# %%
bdi3_entry_test = bdi3_test[bdi3_test['Program Label']=='BDI-3 Eligibility Evaluation']
bdi3_entry_test
# Out:
#        Last Name  First Name  Gender  Date of Birth  \
# 265          NaN         NaN     NaN            NaN
# 423          NaN         NaN     NaN            NaN
# 428          NaN         NaN     NaN            NaN
# 446          NaN         NaN     NaN            NaN
# 654          NaN         NaN     NaN            NaN
# ...          ...         ...     ...            ...
# 25298        NaN         NaN     NaN            NaN
# 25362        NaN         NaN     NaN            NaN
# 25637        NaN         NaN     NaN            NaN
# 25770        NaN         NaN     NaN            NaN
# 25788        NaN         NaN     NaN            NaN
#
#        Location - Root Level (PC)        Location - Root Level (AH)  \
# 265                           NaN  Tennessee Early Intervention Sys
# 423                           NaN  Tennessee Early Intervention Sys
# 428                           NaN  Tennessee Early Intervention Sys
# 446                           NaN  Tennessee Early Intervention Sys
# 654                           NaN  Tennessee Early Intervention Sys
# ...                           ...                               ...
# 25298                         NaN  Tennessee Early Intervention Sys
# 25362                         NaN  Tennessee Early Intervention Sys
# 25637                         NaN  Tennessee Early Intervention Sys
# 25770                         NaN  Tennessee Early Intervention Sys
# 25788                         NaN  Tennessee Early Intervention Sys
#
#       Location - Sub Level 1  Location - Sub Level 2  Location - Sub Level 3  \
# 265            Memphis Delta                     NaN                     NaN
# 423        Greater Nashville                     NaN                     NaN
# 428        Greater Nashville                     NaN                     NaN
# 446          First Tennessee                     NaN                     NaN
# 654            Memphis Delta                     NaN                     NaN
# ...                      ...                     ...                     ...
# 25298         East Tennessee                     NaN                     NaN
# 25362          Memphis Delta                     NaN                     NaN
# 25637       Upper Cumberland                     NaN                     NaN
# 25770         East Tennessee                     NaN                     NaN
# 25788    Southeast Tennessee                     NaN                     NaN
#
#       Child ID  ...  Cognitive-Perception and Concepts RS  \
# 265     486692  ...                                  13.0
# 423     490073  ...                                  10.0
# 428     490134  ...                                  12.0
# 446     490333  ...                                  15.0
# 654     494167  ...                                  12.0
# ...        ...  ...                                   ...
# 25298      NaN  ...                                   1.0
# 25362   564596  ...                                  13.0
# 25637   565093  ...                                  13.0
# 25770   565305  ...                                  13.0
# 25788      NaN  ...                                   8.0
#
#        Cognitive-Perception and Concepts SS  \
# 265                                     7.0
# 423                                     5.0
# 428                                     6.0
# 446                                     8.0
# 654                                     6.0
# ...                                     ...
# 25298                                   1.0
# 25362                                   9.0
# 25637                                   9.0
# 25770                                   9.0
# 25788                                   2.0
#
#        Cognitive-Perception and Concepts PR  \
# 265                                      16
# 423                                       5
# 428                                       9
# 446                                      25
# 654                                       9
# ...                                     ...
# 25298                                    <1
# 25362                                    37
# 25637                                    37
# 25770                                    37
# 25788                                    <1
#
#        Cognitive-Perception and Concepts AE  \
# 265                                      25
# 423                                      15
# 428                                      22
# 446                                      29
# 654                                      22
# ...                                     ...
# 25298                                    <0
# 25362                                    25
# 25637                                    25
# 25770                                    25
# 25788                                     8
#
#        Cognitive-Perception and Concepts RDI  \
# 265                                    27/90
# 423                      1990-04-01 00:00:00
# 428                                    19/90
# 446                                    61/90
# 654                                    19/90
# ...                                      ...
# 25298                                  <1/90
# 25362                                  73/90
# 25637                                  73/90
# 25770                                  73/90
# 25788                                  <1/90
#
#        Cognitive-Perception and Concepts CSS  \
# 265                                    464.0
# 423                                    426.0
# 428                                    451.0
# 446                                    477.0
# 654                                    451.0
# ...                                      ...
# 25298                                  293.0
# 25362                                  464.0
# 25637                                  464.0
# 25770                                  464.0
# 25788                                  395.0
#
#        Cognitive-Perception and Concepts CSS 90%  \
# 265                                    450 - 479
# 423                                    408 - 444
# 428                                    429 - 473
# 446                                    466 - 488
# 654                                    429 - 473
# ...                                          ...
# 25298                                  274 - 313
# 25362                                  450 - 479
# 25637                                  450 - 479
# 25770                                  450 - 479
# 25788                                  376 - 415
#
#        Cognitive-Perception and Concepts Z-Score  \
# 265                                         1.00
# 423                                         1.67
# 428                                         1.33
# 446                                         0.67
# 654                                         1.33
# ...                                          ...
# 25298                                       3.00
# 25362                                       0.33
# 25637                                       0.33
# 25770                                       0.33
# 25788                                       2.67
#
#        Cognitive-Perception and Concepts T-Score  \
# 265                                         40.0
# 423                                         33.0
# 428                                         37.0
# 446                                         43.0
# 654                                         37.0
# ...                                          ...
# 25298                                       20.0
# 25362                                       47.0
# 25637                                       47.0
# 25770                                       47.0
# 25788                                       23.0
#
#       Cognitive-Perception and Concepts NCE
# 265                                      29
# 423                                      15
# 428                                      22
# 446                                      36
# 654                                      22
# ...                                     ...
# 25298                                    <1
# 25362                                    43
# 25637                                    43
# 25770                                    43
# 25788                                    <1
#
# [1265 rows x 228 columns]

# %%
bdi3_exit_test = bdi3_test[bdi3_test['Program Label']=='BDI-3 Milestone or Exit Evaluation']
bdi3_exit_test
# Out:
#        Last Name  First Name  Gender  Date of Birth  \
# 39           NaN         NaN     NaN            NaN
# 252          NaN         NaN     NaN            NaN
# 674          NaN         NaN     NaN            NaN
# 739          NaN         NaN     NaN            NaN
# 910          NaN         NaN     NaN            NaN
# ...          ...         ...     ...            ...
# 24785        NaN         NaN     NaN            NaN
# 25042        NaN         NaN     NaN            NaN
# 25363        NaN         NaN     NaN            NaN
# 25771        NaN         NaN     NaN            NaN
# 25789        NaN         NaN     NaN            NaN
#
#        Location - Root Level (PC)        Location - Root Level (AH)  \
# 39                            NaN  Tennessee Early Intervention Sys
# 252                           NaN  Tennessee Early Intervention Sys
# 674                           NaN  Tennessee Early Intervention Sys
# 739                           NaN  Tennessee Early Intervention Sys
# 910                           NaN  Tennessee Early Intervention Sys
# ...                           ...                               ...
# 24785                         NaN  Tennessee Early Intervention Sys
# 25042                         NaN  Tennessee Early Intervention Sys
# 25363                         NaN  Tennessee Early Intervention Sys
# 25771                         NaN  Tennessee Early Intervention Sys
# 25789                         NaN  Tennessee Early Intervention Sys
#
#       Location - Sub Level 1  Location - Sub Level 2  Location - Sub Level 3  \
# 39          Upper Cumberland                     NaN                     NaN
# 252                Northwest                     NaN                     NaN
# 674                Northwest                     NaN                     NaN
# 739                Southwest                     NaN                     NaN
# 910                Northwest                     NaN                     NaN
# ...                      ...                     ...                     ...
# 24785         East Tennessee                     NaN                     NaN
# 25042         East Tennessee                     NaN                     NaN
# 25363          Memphis Delta                     NaN                     NaN
# 25771         East Tennessee                     NaN                     NaN
# 25789    Southeast Tennessee                     NaN                     NaN
#
#       Child ID  ...  Cognitive-Perception and Concepts RS  \
# 39      478244  ...                                  13.0
# 252     486480  ...                                  11.0
# 674     494403  ...                                  16.0
# 739     495340  ...                                  14.0
# 910     497426  ...                                  12.0
# ...        ...  ...                                   ...
# 24785   563511  ...                                   8.0
# 25042      NaN  ...                                  14.0
# 25363   564596  ...                                  16.0
# 25771   565305  ...                                  22.0
# 25789   565335  ...                                   8.0
#
#        Cognitive-Perception and Concepts SS  \
# 39                                      4.0
# 252                                     5.0
# 674                                     9.0
# 739                                     7.0
# 910                                     6.0
# ...                                     ...
# 24785                                   1.0
# 25042                                   7.0
# 25363                                   9.0
# 25771                                  12.0
# 25789                                   1.0
#
#        Cognitive-Perception and Concepts PR  \
# 39                                        2
# 252                                       5
# 674                                      37
# 739                                      16
# 910                                       9
# ...                                     ...
# 24785                                    <1
# 25042                                    16
# 25363                                    37
# 25771                                    75
# 25789                                    <1
#
#        Cognitive-Perception and Concepts AE  \
# 39                                       25
# 252                                      18
# 674                                      31
# 739                                      28
# 910                                      22
# ...                                     ...
# 24785                                     8
# 25042                                    28
# 25363                                    31
# 25771                                    39
# 25789                                     8
#
#        Cognitive-Perception and Concepts RDI  \
# 39                       1990-01-01 00:00:00
# 252                      1990-02-01 00:00:00
# 674                                    73/90
# 739                                    45/90
# 910                      1990-08-01 00:00:00
# ...                                      ...
# 24785                                  <1/90
# 25042                                  45/90
# 25363                                  73/90
# 25771                                  97/90
# 25789                                  <1/90
#
#        Cognitive-Perception and Concepts CSS  \
# 39                                     464.0
# 252                                    437.0
# 674                                    482.0
# 739                                    471.0
# 910                                    451.0
# ...                                      ...
# 24785                                  395.0
# 25042                                  471.0
# 25363                                  482.0
# 25771                                  505.0
# 25789                                  395.0
#
#        Cognitive-Perception and Concepts CSS 90%  \
# 39                                     450 - 479
# 252                                    421 - 453
# 674                                    471 - 493
# 739                                    459 - 484
# 910                                    429 - 473
# ...                                          ...
# 24785                                  376 - 415
# 25042                                  459 - 484
# 25363                                  471 - 493
# 25771                                  497 - 513
# 25789                                  376 - 415
#
#        Cognitive-Perception and Concepts Z-Score  \
# 39                                          2.00
# 252                                         1.67
# 674                                         0.33
# 739                                         1.00
# 910                                         1.33
# ...                                          ...
# 24785                                       3.00
# 25042                                       1.00
# 25363                                       0.33
# 25771                                       0.67
# 25789                                       3.00
#
#        Cognitive-Perception and Concepts T-Score  \
# 39                                          30.0
# 252                                         33.0
# 674                                         47.0
# 739                                         40.0
# 910                                         37.0
# ...                                          ...
# 24785                                       20.0
# 25042                                       40.0
# 25363                                       47.0
# 25771                                       57.0
# 25789                                       20.0
#
#       Cognitive-Perception and Concepts NCE
# 39                                        8
# 252                                      15
# 674                                      43
# 739                                      29
# 910                                      22
# ...                                     ...
# 24785                                    <1
# 25042                                    29
# 25363                                    43
# 25771                                    64
# 25789                                    <1
#
# [352 rows x 228 columns]

# %%
bdi3_exit_test.sort_values(by=['TEIDS Child ID', 'Adaptive-Self Care Date of Testing'], ascending=[True, False])
# Out:
#        Last Name  First Name  Gender  Date of Birth  \
# 39           NaN         NaN     NaN            NaN
# 252          NaN         NaN     NaN            NaN
# 674          NaN         NaN     NaN            NaN
# 739          NaN         NaN     NaN            NaN
# 910          NaN         NaN     NaN            NaN
# ...          ...         ...     ...            ...
# 24785        NaN         NaN     NaN            NaN
# 25042        NaN         NaN     NaN            NaN
# 25363        NaN         NaN     NaN            NaN
# 25771        NaN         NaN     NaN            NaN
# 25789        NaN         NaN     NaN            NaN
#
#        Location - Root Level (PC)        Location - Root Level (AH)  \
# 39                            NaN  Tennessee Early Intervention Sys
# 252                           NaN  Tennessee Early Intervention Sys
# 674                           NaN  Tennessee Early Intervention Sys
# 739                           NaN  Tennessee Early Intervention Sys
# 910                           NaN  Tennessee Early Intervention Sys
# ...                           ...                               ...
# 24785                         NaN  Tennessee Early Intervention Sys
# 25042                         NaN  Tennessee Early Intervention Sys
# 25363                         NaN  Tennessee Early Intervention Sys
# 25771                         NaN  Tennessee Early Intervention Sys
# 25789                         NaN  Tennessee Early Intervention Sys
#
#       Location - Sub Level 1  Location - Sub Level 2  Location - Sub Level 3  \
# 39          Upper Cumberland                     NaN                     NaN
# 252                Northwest                     NaN                     NaN
# 674                Northwest                     NaN                     NaN
# 739                Southwest                     NaN                     NaN
# 910                Northwest                     NaN                     NaN
# ...                      ...                     ...                     ...
# 24785         East Tennessee                     NaN                     NaN
# 25042         East Tennessee                     NaN                     NaN
# 25363          Memphis Delta                     NaN                     NaN
# 25771         East Tennessee                     NaN                     NaN
# 25789    Southeast Tennessee                     NaN                     NaN
#
#       Child ID  ...  Cognitive-Perception and Concepts RS  \
# 39      478244  ...                                  13.0
# 252     486480  ...                                  11.0
# 674     494403  ...                                  16.0
# 739     495340  ...                                  14.0
# 910     497426  ...                                  12.0
# ...        ...  ...                                   ...
# 24785   563511  ...                                   8.0
# 25042      NaN  ...                                  14.0
# 25363   564596  ...                                  16.0
# 25771   565305  ...                                  22.0
# 25789   565335  ...                                   8.0
#
#        Cognitive-Perception and Concepts SS  \
# 39                                      4.0
# 252                                     5.0
# 674                                     9.0
# 739                                     7.0
# 910                                     6.0
# ...                                     ...
# 24785                                   1.0
# 25042                                   7.0
# 25363                                   9.0
# 25771                                  12.0
# 25789                                   1.0
#
#        Cognitive-Perception and Concepts PR  \
# 39                                        2
# 252                                       5
# 674                                      37
# 739                                      16
# 910                                       9
# ...                                     ...
# 24785                                    <1
# 25042                                    16
# 25363                                    37
# 25771                                    75
# 25789                                    <1
#
#        Cognitive-Perception and Concepts AE  \
# 39                                       25
# 252                                      18
# 674                                      31
# 739                                      28
# 910                                      22
# ...                                     ...
# 24785                                     8
# 25042                                    28
# 25363                                    31
# 25771                                    39
# 25789                                     8
#
#        Cognitive-Perception and Concepts RDI  \
# 39                       1990-01-01 00:00:00
# 252                      1990-02-01 00:00:00
# 674                                    73/90
# 739                                    45/90
# 910                      1990-08-01 00:00:00
# ...                                      ...
# 24785                                  <1/90
# 25042                                  45/90
# 25363                                  73/90
# 25771                                  97/90
# 25789                                  <1/90
#
#        Cognitive-Perception and Concepts CSS  \
# 39                                     464.0
# 252                                    437.0
# 674                                    482.0
# 739                                    471.0
# 910                                    451.0
# ...                                      ...
# 24785                                  395.0
# 25042                                  471.0
# 25363                                  482.0
# 25771                                  505.0
# 25789                                  395.0
#
#        Cognitive-Perception and Concepts CSS 90%  \
# 39                                     450 - 479
# 252                                    421 - 453
# 674                                    471 - 493
# 739                                    459 - 484
# 910                                    429 - 473
# ...                                          ...
# 24785                                  376 - 415
# 25042                                  459 - 484
# 25363                                  471 - 493
# 25771                                  497 - 513
# 25789                                  376 - 415
#
#        Cognitive-Perception and Concepts Z-Score  \
# 39                                          2.00
# 252                                         1.67
# 674                                         0.33
# 739                                         1.00
# 910                                         1.33
# ...                                          ...
# 24785                                       3.00
# 25042                                       1.00
# 25363                                       0.33
# 25771                                       0.67
# 25789                                       3.00
#
#        Cognitive-Perception and Concepts T-Score  \
# 39                                          30.0
# 252                                         33.0
# 674                                         47.0
# 739                                         40.0
# 910                                         37.0
# ...                                          ...
# 24785                                       20.0
# 25042                                       40.0
# 25363                                       47.0
# 25771                                       57.0
# 25789                                       20.0
#
#       Cognitive-Perception and Concepts NCE
# 39                                        8
# 252                                      15
# 674                                      43
# 739                                      29
# 910                                      22
# ...                                     ...
# 24785                                    <1
# 25042                                    29
# 25363                                    43
# 25771                                    64
# 25789                                    <1
#
# [352 rows x 228 columns]

# %%
bdi2_df
